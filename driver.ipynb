# %%
from util1 import func

def start(num):
    return func(int(num)).to_dict(orient='records')

# %%
start(5)
# Out:
# [{'col1': 0, 'col2': 0},
#  {'col1': 1, 'col2': 1},
#  {'col1': 2, 'col2': 4},
#  {'col1': 3, 'col2': 9},
#  {'col1': 4, 'col2': 16}]
